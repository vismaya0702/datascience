# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3])
y=np.array([4,5,6])
#plt.plot(x,y,marker='x',color='r',ms='20', mec='r',mfc='g') # color='r' will make line red   #marker value be given o,s,h,x   #ms is given to change size of marker  #mec is to give edge color  #mfc is marker face color
plt.plot(x,y,'o--r')#marker-line-color     #to show how plot should look
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
